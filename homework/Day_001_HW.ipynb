# %% [markdown]
# # 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# A:Competitions:Two Sigma: Using News to Predict Stock Movements
# 1. 你選的這組資料為何重要
# A:因為對投資有興趣，如果成功做出來，對投資有幫助。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# A:資料是股票市上每天出來的資料，由Intrinio 與Thomson Reuters提供。
# 3. 蒐集而來的資料型態為何
# A:主要以整數為主，紀錄股價，成交量，時間等等資訊
# 4. 這組資料想解決的問題如何評估
# A:主要是要預估股市未來的走向，會以之後確切的走向來跟預期的比，看是否有符合。

# %% [markdown]
# # 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# A:定義業績: 主要提升鑽的金錢為主。收的錢越多，業績越好
# A:假設:主要提供司機理想的載客地點和時間，可以收到最高的收益。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# A:由載客聯盟平台提供相對應資訊，實際的數據，對分析比較有幫助)
# 3. 蒐集而來的資料型態為何
# A:可以分為 1.時間 2.地點 3.距離 3.金錢收益
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# A:將時間輸入，再去運算 哪個地點有最大的金錢收益，再比對 相對應時間 那個地點的收益是否如預期的好。

# %% [markdown]
# # 作業3：
#
# 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#
# 資料夾結構建立規則提醒：ML100 > data資料夾 & homework資料夾 (ipynb檔)
#
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.487

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MSE
    """
    mse = MSE = sum((y-yp)**2)/ len(y)
    return mse
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 271.858
# The Mean absolute error is 13.487
